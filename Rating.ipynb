# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("movies_cleaned.csv")

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5402                               Bad Boys for Life          R     Action
# 5403                              Sonic the Hedgehog         PG     Action
# 5404                                        Dolittle         PG  Adventure
# 5405                            The Call of the Wild         PG  Adventure
# 5406                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  5407.000000  5407.000000  5.407000e+03  5.407000e+03  5.407000e+03
# mean   2001.689846     6.393194  1.153467e+05  3.608856e+07  1.034955e+08
# std      10.532659     0.962755  1.845629e+05  4.159678e+07  1.874721e+08
# min    1980.000000     1.900000  1.950000e+02  6.000000e+03  3.090000e+02
# 25%    1993.000000     5.800000  1.900000e+04  1.000000e+07  1.085234e+07
# 50%    2002.000000     6.500000  5.200000e+04  2.200000e+07  3.729544e+07
# 75%    2011.000000     7.100000  1.300000e+05  4.500000e+07  1.130424e+08
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime          day
# count  5407.000000  5407.000000
# mean    108.169595    16.102645
# std      18.122898     8.489314
# min      63.000000     1.000000
# 25%      95.000000     9.000000
# 50%     105.000000    16.000000
# 75%     118.000000    23.000000
# max     271.000000    31.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5407 entries, 0 to 5406
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5407 non-null   object
#  1   rating    5407 non-null   object
#  2   genre     5407 non-null   object
#  3   year      5407 non-null   int64
#  4   released  5407 non-null   object
#  5   score     5407 non-null   float64
#  6   votes     5407 non-null   float64
#  7   director  5407 non-null   object
#  8   writer    5407 non-null   object
#  9   star      5407 non-null   object
#  10  country   5407 non-null   object
#  11  budget    5407 non-null   float64
#  12  gross     5407 non-null   float64
#  13  company   5407 non-null   object
#  14  runtime   5407 non-null   float64
#  15  month     5407 non-null   object
#  16  day       5407 non-null   int64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 718.2+ KB

# %%
#Rating Analysis

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x="rating", y="score", data=df)
# Out:
# <Axes: xlabel='rating', ylabel='score'>

# %%
#All the different ratings didn't have much deviation between them. However, the "Approved" rating stood out as the rating with the least average score. Rating X was the most successful in terms of average score just by a slight amount

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x="rating", y="votes", data=df)
# Out:
# <Axes: xlabel='rating', ylabel='votes'>

# %%
#This graph was very different from the last one. This is because the success of the movie is now being measured based on votes. PG-13 had the maximum amount of average votes and G was right behind it. The least number of votes by a huge amount was in the Approved column.

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x="rating", y="gross", data=df)
# Out:
# <Axes: xlabel='rating', ylabel='gross'>
